# %%
# Mengimpor library yang diperlukan
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Mengimpor dataset
dataset = pd.read_csv('heart.csv')

# %%
dataset
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp
# 0     63    1   3     145   233    1        0       150     0      2.3    0  \
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
X = dataset.iloc[:, 0:13].values
y = dataset.iloc[:, 13].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Mengimpor library Keras dan turunannya
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Inisialisasi ANN
MesinKlasifikasi = Sequential()

# %%
# Menambah input layer dan hidden layer pertama
MesinKlasifikasi.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu', input_dim = 13))

# %%
# Menambah hidden layer kedua
MesinKlasifikasi.add(Dense(units = 7, kernel_initializer = 'uniform', activation = 'relu'))

# %%
# Menambah output layer
MesinKlasifikasi.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
# Compile the model
MesinKlasifikasi.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])

# %%
# Fitting ANN ke training set
MesinKlasifikasi.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 2s 5ms/step - loss: 0.2499 - mse: 0.2499
# Epoch 2/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2494 - mse: 0.2494
# Epoch 3/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2476 - mse: 0.2476
# Epoch 4/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2433 - mse: 0.2433
# Epoch 5/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2347 - mse: 0.2347
# Epoch 6/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2207 - mse: 0.2207
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2012 - mse: 0.2012
# Epoch 8/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1795 - mse: 0.1795
# Epoch 9/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1589 - mse: 0.1589
# Epoch 10/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1423 - mse: 0.1423
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1304 - mse: 0.1304
# Epoch 12/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1232 - mse: 0.1232
# Epoch 13/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1178 - mse: 0.1178
# Epoch 14/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1148 - mse: 0.1148
# Epoch 15/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1118 - mse: 0.1118
# Epoch 16/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1101 - mse: 0.1101
# Epoch 17/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1085 - mse: 0.1085
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1076 - mse: 0.1076
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1063 - mse: 0.1063
# Epoch 20/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1054 - mse: 0.1054
# Epoch 21/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1048 - mse: 0.1048
# Epoch 22/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1038 - mse: 0.1038
# Epoch 23/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1031 - mse: 0.1031
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1026 - mse: 0.1026
# Epoch 25/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1020 - mse: 0.1020
# Epoch 26/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1016 - mse: 0.1016
# Epoch 27/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1010 - mse: 0.1010
# Epoch 28/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1006 - mse: 0.1006
# Epoch 29/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0999 - mse: 0.0999
# Epoch 30/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0994 - mse: 0.0994
# Epoch 31/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0992 - mse: 0.0992
# Epoch 32/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0985 - mse: 0.0985
# Epoch 33/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0980 - mse: 0.0980
# Epoch 34/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0977 - mse: 0.0977
# Epoch 35/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0974 - mse: 0.0974
# Epoch 36/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0967 - mse: 0.0967
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0965 - mse: 0.0965
# Epoch 38/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0960 - mse: 0.0960
# Epoch 39/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0955 - mse: 0.0955
# Epoch 40/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0951 - mse: 0.0951
# Epoch 41/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0947 - mse: 0.0947
# Epoch 42/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0944 - mse: 0.0944
# Epoch 43/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0940 - mse: 0.0940
# Epoch 44/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0936 - mse: 0.0936
# Epoch 45/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0932 - mse: 0.0932
# Epoch 46/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0928 - mse: 0.0928
# Epoch 47/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0926 - mse: 0.0926
# Epoch 48/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0923 - mse: 0.0923
# Epoch 49/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0920 - mse: 0.0920
# Epoch 50/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0914 - mse: 0.0914
# Epoch 51/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0911 - mse: 0.0911
# Epoch 52/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0910 - mse: 0.0910
# Epoch 53/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0904 - mse: 0.0904
# Epoch 54/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0902 - mse: 0.0902
# Epoch 55/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0897 - mse: 0.0897
# Epoch 56/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0894 - mse: 0.0894
# Epoch 57/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0890 - mse: 0.0890
# Epoch 58/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0887 - mse: 0.0887
# Epoch 59/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0886 - mse: 0.0886
# Epoch 60/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0884 - mse: 0.0884
# Epoch 61/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0879 - mse: 0.0879
# Epoch 62/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0878 - mse: 0.0878
# Epoch 63/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0874 - mse: 0.0874
# Epoch 64/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0870 - mse: 0.0870
# Epoch 65/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0869 - mse: 0.0869
# Epoch 66/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0864 - mse: 0.0864
# Epoch 67/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0863 - mse: 0.0863
# Epoch 68/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0860 - mse: 0.0860
# Epoch 69/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0859 - mse: 0.0859
# Epoch 70/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0856 - mse: 0.0856
# Epoch 71/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0854 - mse: 0.0854
# Epoch 72/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0850 - mse: 0.0850
# Epoch 73/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0851 - mse: 0.0851
# Epoch 74/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0847 - mse: 0.0847
# Epoch 75/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0844 - mse: 0.0844
# Epoch 76/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0843 - mse: 0.0843
# Epoch 77/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0841 - mse: 0.0841
# Epoch 78/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0838 - mse: 0.0838
# Epoch 79/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0835 - mse: 0.0835
# Epoch 80/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0836 - mse: 0.0836
# Epoch 81/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0833 - mse: 0.0833
# Epoch 82/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0831 - mse: 0.0831
# Epoch 83/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0829 - mse: 0.0829
# Epoch 84/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0825 - mse: 0.0825
# Epoch 85/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0825 - mse: 0.0825
# Epoch 86/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0824 - mse: 0.0824
# Epoch 87/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0822 - mse: 0.0822
# Epoch 88/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0819 - mse: 0.0819
# Epoch 89/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0818 - mse: 0.0818
# Epoch 90/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0816 - mse: 0.0816
# Epoch 91/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0815 - mse: 0.0815
# Epoch 92/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0812 - mse: 0.0812
# Epoch 93/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0810 - mse: 0.0810
# Epoch 94/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0807 - mse: 0.0807
# Epoch 95/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0806 - mse: 0.0806
# Epoch 96/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0803 - mse: 0.0803
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0802 - mse: 0.0802
# Epoch 98/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0801 - mse: 0.0801
# Epoch 99/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0798 - mse: 0.0798
# Epoch 100/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0795 - mse: 0.0795

# %%
# Memprediksi hasil test set
y_pred = MesinKlasifikasi.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 10ms/step

# %%
y_pred = (y_pred > 0.5)

# %%
# Membuat confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# Menghitung True Positives, True Negatives, dan Total
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]
TP = cm[1, 1]
total = TN + FP + FN + TP

# Menghitung akurasi
accuracy = (TP + TN) / total
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.868421052631579
